# %%
import glob
import random

from keras.applications import EfficientNetB0
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from PIL import Image
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
import tensorflow as tf
from keras import datasets, layers, models
from keras.applications.efficientnet import preprocess_input
from keras.callbacks import EarlyStopping
from imblearn.over_sampling import RandomOverSampler

# %%
washington_data = pd.DataFrame([file for file in glob.iglob("../data/**/*.jpg", recursive=True)])
washington_data = pd.DataFrame(washington_data[0])
washington_data['image_data'] = washington_data[0].apply(lambda x : np.asarray(Image.open(x)))
# Change file system parsing to be mac-friendly
washington_data[[0, 1, 'parent_file_path', 'name','image_id']] = washington_data[0].str.split("/", expand = True)[[0,1,2,3,4]]
print(washington_data)
# Out:
#        0                                         image_data     1  \
# 0     ..  [[[125, 167, 243], [121, 163, 239], [115, 158,...  data
# 1     ..  [[[29, 16, 44], [40, 28, 50], [33, 25, 36], [2...  data
# 2     ..  [[[98, 101, 106], [108, 111, 116], [119, 122, ...  data
# 3     ..  [[[79, 86, 96], [80, 87, 97], [81, 88, 98], [8...  data
# 4     ..  [[[66, 76, 86], [67, 77, 87], [68, 78, 88], [7...  data
# ...   ..                                                ...   ...
# 4620  ..  [[[149, 202, 244], [149, 202, 244], [149, 202,...  data
# 4621  ..  [[[167, 190, 204], [175, 198, 212], [179, 202,...  data
# 4622  ..  [[[220, 227, 233], [220, 227, 233], [220, 227,...  data
# 4623  ..  [[[12, 64, 199], [13, 65, 200], [15, 67, 202],...  data
# 4624  ..  [[[226, 227, 229], [226, 227, 229], [226, 227,...  data
#
#      parent_file_path                                   name  \
# 0              Images  Redondo Beach, Des Moines, Washington
# 1              Images  Redondo Beach, Des Moines, Washington
# 2              Images  Redondo Beach, Des Moines, Washington
# 3              Images  Redondo Beach, Des Moines, Washington
# 4              Images  Redondo Beach, Des Moines, Washington
# ...               ...                                    ...
# 4620           Images               Lenore Lake (Washington)
# 4621           Images               Lenore Lake (Washington)
# 4622           Images               Lenore Lake (Washington)
# 4623           Images               Lenore Lake (Washington)
# 4624           Images               Lenore Lake (Washington)
#
#                   image_id
# 0     fb4e60c89208fa17.jpg
# 1     c7ef5dadf1372bf1.jpg
# 2     bc48f76ef39e0d0d.jpg
# 3     3b0667738a4bccc7.jpg
# 4     6e2bba4bd85e650a.jpg
# ...                    ...
# 4620  0096ddca55c7058a.jpg
# 4621  b4e3c66492af9a0a.jpg
# 4622  32279bb54e244c9c.jpg
# 4623  a9047a6b069c970d.jpg
# 4624  b48c6e5e197c3840.jpg
#
# [4625 rows x 6 columns]

# %%
washington_data_cleaned = washington_data[['name', 'image_id', 'image_data']]

# %%
encoder = OneHotEncoder(handle_unknown='ignore')
encoder.fit(pd.DataFrame(washington_data_cleaned['name']))

labels_onehot = encoder.transform(pd.DataFrame(washington_data_cleaned['name'])).toarray()

# %%
washington_images_stack = np.stack(washington_data_cleaned['image_data'], axis=0)

# %%
x_train, x_test, y_train, y_test = train_test_split(washington_images_stack, labels_onehot, test_size=0.2, stratify=labels_onehot)

# %%
x_train, x_val, y_train, y_val = train_test_split(
x_train, y_train, test_size=0.2, stratify=y_train
) # 0.16 = validation set

x_train_flat = x_train.reshape(x_train.shape[0], -1)

ros = RandomOverSampler(random_state=42)
x_train_res, y_train_res = ros.fit_resample(x_train_flat, y_train)

# %%
num_classes = washington_data_cleaned['name'].nunique()
print(num_classes)
# Out:
# 296

# %%
dropout_rate = 0.3
img_dimension = (224, 224, 3)

data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomTranslation(0.1, 0.1),
    layers.RandomBrightness(0.1),
    layers.RandomContrast(0.1)
], name="data_augmentation")

# takes input data, augments, and preps it for EfficientNetB0
inputs = layers.Input(shape=img_dimension)
x = data_augmentation(inputs) 
x = preprocess_input(x)

# preps EfficientNetB0 model (with its weights) to train with our model
base_model = EfficientNetB0(include_top=False, input_tensor=None, weights='imagenet')
base_model.trainable = False

# layers to train the model with our data
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)

x = layers.BatchNormalization()(x)
x = layers.Dropout(dropout_rate)(x)
outputs = layers.Dense(num_classes, activation='softmax')(x)

model = models.Model(inputs, outputs)

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
auc_metric = tf.keras.metrics.AUC(multi_label=True)
top_five_accuracy_metric = tf.keras.metrics.TopKCategoricalAccuracy(k=5)

EPOCHS = 10 
BATCH_SIZE = 64

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
              metrics=['accuracy', auc_metric, top_five_accuracy_metric])

history = model.fit(
    x_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data = (x_val, y_val),
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 31s 563ms/step - accuracy: 0.8982 - auc_2: 0.8341 - loss: 0.3853 - top_k_categorical_accuracy: 0.9910 - val_accuracy: 0.7135 - val_auc_2: 0.8320 - val_loss: 1.0897 - val_top_k_categorical_accuracy: 0.9095
# Epoch 2/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 26s 561ms/step - accuracy: 0.9223 - auc_2: 0.8457 - loss: 0.3265 - top_k_categorical_accuracy: 0.9924 - val_accuracy: 0.7257 - val_auc_2: 0.8357 - val_loss: 1.0316 - val_top_k_categorical_accuracy: 0.9162
# Epoch 3/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 28s 591ms/step - accuracy: 0.9302 - auc_2: 0.8290 - loss: 0.2713 - top_k_categorical_accuracy: 0.9958 - val_accuracy: 0.7297 - val_auc_2: 0.8345 - val_loss: 1.0345 - val_top_k_categorical_accuracy: 0.9176
# Epoch 4/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 26s 562ms/step - accuracy: 0.9351 - auc_2: 0.8253 - loss: 0.2620 - top_k_categorical_accuracy: 0.9928 - val_accuracy: 0.7351 - val_auc_2: 0.8315 - val_loss: 1.0203 - val_top_k_categorical_accuracy: 0.9176
# Epoch 5/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 27s 577ms/step - accuracy: 0.9351 - auc_2: 0.8265 - loss: 0.2396 - top_k_categorical_accuracy: 0.9947 - val_accuracy: 0.7284 - val_auc_2: 0.8341 - val_loss: 1.0199 - val_top_k_categorical_accuracy: 0.9189
# Epoch 6/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 26s 548ms/step - accuracy: 0.9476 - auc_2: 0.8434 - loss: 0.2047 - top_k_categorical_accuracy: 0.9970 - val_accuracy: 0.7230 - val_auc_2: 0.8302 - val_loss: 1.0373 - val_top_k_categorical_accuracy: 0.9216
# Epoch 7/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 25s 543ms/step - accuracy: 0.9474 - auc_2: 0.8339 - loss: 0.2153 - top_k_categorical_accuracy: 0.9958 - val_accuracy: 0.7324 - val_auc_2: 0.8247 - val_loss: 1.0453 - val_top_k_categorical_accuracy: 0.9095
# Epoch 8/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 27s 582ms/step - accuracy: 0.9516 - auc_2: 0.8325 - loss: 0.1942 - top_k_categorical_accuracy: 0.9948 - val_accuracy: 0.7351 - val_auc_2: 0.8219 - val_loss: 1.0292 - val_top_k_categorical_accuracy: 0.9189
# Epoch 9/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 27s 575ms/step - accuracy: 0.9539 - auc_2: 0.8302 - loss: 0.1737 - top_k_categorical_accuracy: 0.9983 - val_accuracy: 0.7311 - val_auc_2: 0.8218 - val_loss: 1.0292 - val_top_k_categorical_accuracy: 0.9243
# Epoch 10/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 27s 571ms/step - accuracy: 0.9564 - auc_2: 0.8188 - loss: 0.1680 - top_k_categorical_accuracy: 0.9973 - val_accuracy: 0.7176 - val_auc_2: 0.8177 - val_loss: 1.0350 - val_top_k_categorical_accuracy: 0.9122

# %%
model.save('224x224 image classification EfficientNetB0 Train Split oversampling_2.keras')

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

plt.show()

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower right')

plt.show()

# %%
print(history.history.keys())
plt.plot(history.history['auc_2'], label='auc')
plt.plot(history.history['val_auc_2'], label = 'val_auc')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(loc='lower right')
plt.ylim(0.78,1.1)
plt.show()
# Out:
# dict_keys(['accuracy', 'auc_2', 'loss', 'top_k_categorical_accuracy', 'val_accuracy', 'val_auc_2', 'val_loss', 'val_top_k_categorical_accuracy'])

# %%
model = tf.keras.models.load_model('224x224 image classification EfficientNetB0 Train Split oversampling_2.keras')

# %%
from skimage.transform import resize

def load_image( infilename ) :
    img = Image.open( infilename )
    img.load()
    data = np.asarray( img, dtype="uint8" )
    return data

img_needle = load_image("personal_test_images/space_needle_1.jpg")
img_chinatown = load_image("personal_test_images/Chinatown_gate.jpg")
img_library = load_image("personal_test_images/suzzalo.jpeg")
img_fountain = load_image("personal_test_images/fountain.jpg")

img_needle_resized = resize(np.array(img_needle), (224, 224, 3), anti_aliasing=True)
img_chinatown_resized = resize(np.array(img_chinatown), (224, 224, 3), anti_aliasing=True)
img_library_resized = resize(np.array(img_library), (224, 224, 3), anti_aliasing=True)
img_fountain_resized = resize(np.array(img_fountain), (224, 224, 3), anti_aliasing=True)

img_needle_resized = preprocess_input(img_needle_resized * 255).astype(int)
img_chinatown_resized = preprocess_input(img_chinatown_resized * 255).astype(int)
img_library_resized = preprocess_input(img_library_resized * 255).astype(int)
img_fountain_resized = preprocess_input(img_fountain_resized * 255).astype(int)

print(img_needle_resized)

image_batch = np.array([img_needle_resized, img_chinatown_resized, img_library_resized, img_fountain_resized])

output = model.predict(image_batch)
output
# Out:
# [[[198 211 227]
#   [199 212 228]
#   [199 212 228]
#   ...
#   [194 207 223]
#   [195 208 224]
#   [195 208 224]]
#
#  [[198 211 227]
#   [198 211 227]
#   [198 211 227]
#   ...
#   [194 207 223]
#   [195 208 224]
#   [195 208 224]]
#
#  [[198 211 227]
#   [198 211 227]
#   [198 211 227]
#   ...
#   [195 208 224]
#   [194 207 223]
#   [194 207 223]]
#
#  ...
#
#  [[  7  16  21]
#   [ 16  26  26]
#   [ 24  35  32]
#   ...
#   [ 58  62  62]
#   [ 58  62  63]
#   [ 60  65  67]]
#
#  [[  5  14  19]
#   [ 10  19  23]
#   [ 16  26  26]
#   ...
#   [113 103 100]
#   [116 106 103]
#   [118 109 106]]
#
#  [[  7  16  21]
#   [  7  15  19]
#   [ 16  24  25]
#   ...
#   [114  95  87]
#   [116  97  89]
#   [114  96  87]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 810ms/step
# array([[7.16089635e-05, 3.37277763e-02, 3.77948782e-05, ...,
#         1.18204605e-06, 4.75710385e-06, 1.40936905e-07],
#        [5.88365765e-06, 7.57688467e-05, 1.01968490e-05, ...,
#         1.49402031e-05, 1.49598287e-04, 2.72506569e-03],
#        [1.82952764e-08, 1.54110035e-06, 1.07738444e-07, ...,
#         1.53439473e-07, 4.76702917e-06, 1.97480404e-06],
#        [1.29588802e-08, 5.60127766e-08, 7.39402196e-07, ...,
#         3.04624486e-08, 2.66046982e-07, 1.22514905e-07]], dtype=float32)

# %%
classes = washington_data_cleaned['name'].unique()
classes = np.sort(classes)
for picture in output:
    guesses = np.argsort(picture)[-5:]
    print(np.round(picture[guesses][::-1], 3))

    for guess in guesses[::-1]:
        print(classes[guess])
        
    print("----------")
# Out:
# [0.896 0.058 0.034 0.004 0.001]
# Space Needle
# Belltown, Seattle, Washington
# 1201 Third Avenue Tower
# Olympic Sculpture Park
# Central Waterfront, Seattle, Washington
# ----------
# [0.419 0.134 0.07  0.065 0.037]
# Alaskan Way Viaduct
# Historic Chinatown Gate (Seattle)
# Pioneer Square, Seattle, Washington
# Elliott Bay
# King Street Station (Seattle)
# ----------
# [0.992 0.006 0.001 0.    0.   ]
# Suzzallo Library
# Washington State Capitol
# University Unitarian Church
# Officers Row
# Paradise Inn
# ----------
# [0.999 0.    0.    0.    0.   ]
# Drumheller Fountain
# Comet Falls
# International Fountain, Seattle Center
# Lake View Cemetery, Seattle
# Suzzallo Library
# ----------

# %% [markdown]
# # TEST IMAGE ONE
# SPACE NEEDLE

# %%
plt.imshow(img_needle_resized)

# %% [markdown]
# # TEST IMAGE TWO
# INTERNATIONAL DISTRICT

# %%
plt.imshow(img_chinatown_resized)

# %% [markdown]
# # TEST IMAGE THREE
# SUZZALO LIBRARY (UW)

# %%
plt.imshow(img_library_resized)

# %% [markdown]
# # TEST IMAGE FOUR
# Drumheller Fountain (UW)

# %%
plt.imshow(img_fountain_resized)

# %% [markdown]
# # TESTING:

# %%
test_output = model.predict(x_test)
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 212ms/step

# %%
# x_test: numpy array of pixel values: 
# y_test: numpy array of one-hot encoded label
# test_output: array of arrays that contain probabilities for each label
index = 0 
num_correct = 0

# Check if correct ouptut is in the top 5:
for one_test_output in test_output: 
    guesses = np.argsort(one_test_output)[-5:]
    # print(np.round(one_test_output[guesses][::-1], 3))
    actual_test_label_index = np.argmax(y_test[index])
    actual_label = classes[actual_test_label_index]
    # print("ACTUAL LABEL: ", actual_label)
    prioritized_guesses = guesses[::-1]
    guess_labels = [1,1,1,1,1]
    for i in range(0,5):
        guess_labels[i] = classes[prioritized_guesses[i]]
        
    # print("----------")
    # print(guess_labels)
    # print(guesses[::-1])
    if actual_label in guess_labels:
        num_correct += 1
    
    
    index +=1 

index=0
test_len = len(x_test)
print(num_correct)
print(num_correct/test_len)

print(test_output)
inaccurate_guess_confidence = []
## Check if correct output is in the most confident output: 
for single_guess_output in test_output: 
    guesses = np.argsort(single_guess_output)[-1:]
    # print(guesses)
    actual_test_label_index = np.argmax(y_test[index])
    actual_label = classes[actual_test_label_index]
    
    prioritized_guesses = guesses[::-1]
    guess = classes[prioritized_guesses[0]]
    index+=1
    
    if guess != actual_label: 
        inaccurate_guess_confidence.append(single_guess_output[prioritized_guesses[0]])

        
        
    
pd.DataFrame(inaccurate_guess_confidence).describe()
mean_value = np.mean(inaccurate_guess_confidence)
median_value = np.median(inaccurate_guess_confidence)
plt.boxplot(inaccurate_guess_confidence)
plt.scatter(1, mean_value, color='red', zorder=3)  # Plot the mean point
plt.text(1.09, mean_value, f'Mean: {mean_value:.3f}', color='red')
plt.text(1.08, median_value, f'Median: {median_value: .3f}', color='darkorange')
plt.ylabel("Model Confidence of Top Guess")
plt.title("Distribution of Top Guess Confidence when Incorreect")
# Out:
# 851
# 0.92
# [[2.31948967e-08 6.01448335e-07 7.46369910e-10 ... 9.64485025e-09
#   7.07343695e-09 1.88831955e-08]
#  [1.46222483e-05 2.08778860e-04 4.51278756e-05 ... 1.98150574e-05
#   2.48147371e-05 1.08622866e-04]
#  [1.53778801e-05 4.23495266e-07 5.76915318e-06 ... 4.87167063e-06
#   2.18176683e-06 7.43623843e-07]
#  ...
#  [5.17968088e-04 2.06296645e-05 1.68591177e-05 ... 2.88988281e-06
#   4.14546594e-05 1.29259701e-04]
#  [1.07173221e-08 2.00706481e-07 4.52299446e-07 ... 1.73823003e-06
#   1.44824597e-08 2.31399024e-08]
#  [1.20622586e-04 1.20481918e-05 8.24857295e-07 ... 1.34749716e-05
#   6.85422947e-06 1.47551461e-03]]
# Text(0.5, 1.0, 'Distribution of Top Guess Confidence when Incorreect')
