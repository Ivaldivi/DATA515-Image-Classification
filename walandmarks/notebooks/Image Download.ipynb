# %%
from io import BytesIO
from PIL import Image
import time

import numpy as np
from pandarallel import pandarallel
import pandas as pd
import requests
from skimage.transform import resize

# %%
# Left join of clean_images & full
clean_images = pd.read_csv("../data/landmarks_washington_clean_images.csv")
full_images = pd.read_csv("../data/landmarks_washington_full.csv")
clean_left = pd.merge(clean_images, full_images, on="landmark_id", how="left")

clean_left
# Out:
#       landmark_id          image_id  \
# 0             262  1272ef793ebba7a2
# 1             262  3f509df1d66997a0
# 2             262  a263751cf3b9d364
# 3             262  9981810cd64b2e5b
# 4             262  172999b2cc578a66
# ...           ...               ...
# 4629       203087  1ee045e5a3bc9568
# 4630       203087  adb2a9e25454e0d1
# 4631       203087  3d904df7f6c9f92a
# 4632       203087  3895947116add663
# 4633       203087  146cc06310d08ef0
#
#                                                     url             name  \
# 0     https://upload.wikimedia.org/wikipedia/commons...      Comet Falls
# 1     https://upload.wikimedia.org/wikipedia/commons...      Comet Falls
# 2     https://upload.wikimedia.org/wikipedia/commons...      Comet Falls
# 3     https://upload.wikimedia.org/wikipedia/commons...      Comet Falls
# 4     https://upload.wikimedia.org/wikipedia/commons...      Comet Falls
# ...                                                 ...              ...
# 4629  https://upload.wikimedia.org/wikipedia/commons...  Jack Block Park
# 4630  https://upload.wikimedia.org/wikipedia/commons...  Jack Block Park
# 4631  https://upload.wikimedia.org/wikipedia/commons...  Jack Block Park
# 4632  https://upload.wikimedia.org/wikipedia/commons...  Jack Block Park
# 4633  https://upload.wikimedia.org/wikipedia/commons...  Jack Block Park
#
#      supercategory                                           location  \
# 0        waterfall  Mount Rainier National Park,Lewis County,Washi...
# 1        waterfall  Mount Rainier National Park,Lewis County,Washi...
# 2        waterfall  Mount Rainier National Park,Lewis County,Washi...
# 3        waterfall  Mount Rainier National Park,Lewis County,Washi...
# 4        waterfall  Mount Rainier National Park,Lewis County,Washi...
# ...            ...                                                ...
# 4629          park  Seattle,King County,Washington,Pacific Northwe...
# 4630          park  Seattle,King County,Washington,Pacific Northwe...
# 4631          park  Seattle,King County,Washington,Pacific Northwe...
# 4632          park  Seattle,King County,Washington,Pacific Northwe...
# 4633          park  Seattle,King County,Washington,Pacific Northwe...
#
#       latitude  longitude                                           category
# 0      46.7958    121.780  http://commons.wikimedia.org/wiki/Category:Com...
# 1      46.7958    121.780  http://commons.wikimedia.org/wiki/Category:Com...
# 2      46.7958    121.780  http://commons.wikimedia.org/wiki/Category:Com...
# 3      46.7958    121.780  http://commons.wikimedia.org/wiki/Category:Com...
# 4      46.7958    121.780  http://commons.wikimedia.org/wiki/Category:Com...
# ...        ...        ...                                                ...
# 4629   47.5831    122.371  http://commons.wikimedia.org/wiki/Category:Jac...
# 4630   47.5831    122.371  http://commons.wikimedia.org/wiki/Category:Jac...
# 4631   47.5831    122.371  http://commons.wikimedia.org/wiki/Category:Jac...
# 4632   47.5831    122.371  http://commons.wikimedia.org/wiki/Category:Jac...
# 4633   47.5831    122.371  http://commons.wikimedia.org/wiki/Category:Jac...
#
# [4634 rows x 9 columns]

# %%
# selects the important fields
url_matrix = clean_left[["image_id", "name", "url"]]

# %%
# pandarallel requires functions to be self-contained
# imports have to be *in* the function

# Get image data from the url
def get_image_from_url(url):    
    def image_bytes_to_ndarray(image_bytes):
        imgSize = (224, 224, 3)
        
        """
        Converts image bytes to a NumPy ndarray.
        """
        image_buffer = BytesIO(image_bytes.content)
        img = Image.open(image_buffer)

        return resize(np.array(img), imgSize, anti_aliasing=True)
        
    header = {
        "User-Agent": "MyImageScraper/1.0 (ivaldivi@uw.edu)"
    }

    time.sleep(0.5)
    try:
        image_bytes = requests.get(url, headers=header)
        image_ndarray = image_bytes_to_ndarray(image_bytes)
        
        return image_ndarray
    except Exception as e:
        print(e)
        print(url)

        # maybe replace with None
        return 0

# %%
pandarallel.initialize(progress_bar=True)
url_matrix["image_data"] = url_matrix["url"].parallel_apply(get_image_from_url)

url_matrix
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
#
# WARNING: You are on Windows. If you detect any issue with pandarallel, be sure you checked out the Troubleshooting page:
# https://nalepae.github.io/pandarallel/troubleshooting/
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=616), Label(value='0 / 616'))), HB…
# C:\Users\antho\AppData\Local\Temp\ipykernel_18844\1078002829.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   url_matrix["image_data"] = url_matrix["url"].parallel_apply(get_image_from_url)
#               image_id             name  \
# 0     1272ef793ebba7a2      Comet Falls
# 1     3f509df1d66997a0      Comet Falls
# 2     a263751cf3b9d364      Comet Falls
# 3     9981810cd64b2e5b      Comet Falls
# 4     172999b2cc578a66      Comet Falls
# ...                ...              ...
# 4921  1ee045e5a3bc9568  Jack Block Park
# 4922  adb2a9e25454e0d1  Jack Block Park
# 4923  3d904df7f6c9f92a  Jack Block Park
# 4924  3895947116add663  Jack Block Park
# 4925  146cc06310d08ef0  Jack Block Park
#
#                                                     url  \
# 0     https://upload.wikimedia.org/wikipedia/commons...
# 1     https://upload.wikimedia.org/wikipedia/commons...
# 2     https://upload.wikimedia.org/wikipedia/commons...
# 3     https://upload.wikimedia.org/wikipedia/commons...
# 4     https://upload.wikimedia.org/wikipedia/commons...
# ...                                                 ...
# 4921  https://upload.wikimedia.org/wikipedia/commons...
# 4922  https://upload.wikimedia.org/wikipedia/commons...
# 4923  https://upload.wikimedia.org/wikipedia/commons...
# 4924  https://upload.wikimedia.org/wikipedia/commons...
# 4925  https://upload.wikimedia.org/wikipedia/commons...
#
#                                              image_data
# 0     [[[0.045279937331769195, 0.05800154655315033, ...
# 1     [[[0.10766877129296296, 0.11505473672808664, 0...
# 2     [[[0.3236976619132381, 0.38716444778770953, 0....
# 3     [[[0.17229581146720963, 0.20344506205558716, 0...
# 4     [[[0.10171972078135477, 0.1445214264506818, 0....
# ...                                                 ...
# 4921  [[[0.7919118090282239, 0.803956406834169, 0.83...
# 4922  [[[0.697539078858799, 0.70100082725661, 0.7260...
# 4923  [[[0.7672072532084186, 0.7914357164157996, 0.8...
# 4924  [[[0.8056955604115225, 0.7691280361152044, 0.7...
# 4925  [[[0.7073109454651275, 0.7229954104987624, 0.7...
#
# [4926 rows x 4 columns]

# %%
# Null images are stored as int(0), so it filters them out
# also filters out any potential NA entries from the data scraping
url_matrix_cleaned = url_matrix.loc[url_matrix['image_data'].apply(lambda x: type(x) != int)]
url_matrix_cleaned = url_matrix_cleaned.loc[url_matrix_cleaned['image_data'].notna()]

# %%
url_matrix_cleaned
# Out:
#               image_id             name  \
# 0     1272ef793ebba7a2      Comet Falls
# 1     3f509df1d66997a0      Comet Falls
# 2     a263751cf3b9d364      Comet Falls
# 3     9981810cd64b2e5b      Comet Falls
# 4     172999b2cc578a66      Comet Falls
# ...                ...              ...
# 4921  1ee045e5a3bc9568  Jack Block Park
# 4922  adb2a9e25454e0d1  Jack Block Park
# 4923  3d904df7f6c9f92a  Jack Block Park
# 4924  3895947116add663  Jack Block Park
# 4925  146cc06310d08ef0  Jack Block Park
#
#                                                     url  \
# 0     https://upload.wikimedia.org/wikipedia/commons...
# 1     https://upload.wikimedia.org/wikipedia/commons...
# 2     https://upload.wikimedia.org/wikipedia/commons...
# 3     https://upload.wikimedia.org/wikipedia/commons...
# 4     https://upload.wikimedia.org/wikipedia/commons...
# ...                                                 ...
# 4921  https://upload.wikimedia.org/wikipedia/commons...
# 4922  https://upload.wikimedia.org/wikipedia/commons...
# 4923  https://upload.wikimedia.org/wikipedia/commons...
# 4924  https://upload.wikimedia.org/wikipedia/commons...
# 4925  https://upload.wikimedia.org/wikipedia/commons...
#
#                                              image_data
# 0     [[[0.045279937331769195, 0.05800154655315033, ...
# 1     [[[0.10766877129296296, 0.11505473672808664, 0...
# 2     [[[0.3236976619132381, 0.38716444778770953, 0....
# 3     [[[0.17229581146720963, 0.20344506205558716, 0...
# 4     [[[0.10171972078135477, 0.1445214264506818, 0....
# ...                                                 ...
# 4921  [[[0.7919118090282239, 0.803956406834169, 0.83...
# 4922  [[[0.697539078858799, 0.70100082725661, 0.7260...
# 4923  [[[0.7672072532084186, 0.7914357164157996, 0.8...
# 4924  [[[0.8056955604115225, 0.7691280361152044, 0.7...
# 4925  [[[0.7073109454651275, 0.7229954104987624, 0.7...
#
# [4917 rows x 4 columns]

# %%
def download_image(row):
    name = row['name']
    img_id = row['image_id']

    path = f"data/{name}"
    filename = f"{path}/{img_id}.jpg"

    image = row['image_data']
    
    if not os.path.exists(path):
        os.mkdir(path)

    # images stored as 224x224,3 of (0 - 255)
    # multiply the original array (stored as 0-1) to scale for (0-255)
    im = Image.fromarray((image * 255).astype(np.uint8))
    im.save(filename)

# %%
url_matrix_cleaned.apply(lambda x: download_image(x), axis=1)
